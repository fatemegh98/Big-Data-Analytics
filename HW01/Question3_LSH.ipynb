# %%
# !pip install PyDrive
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.7/dist-packages (1.3.1)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.7/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.7/dist-packages (from PyDrive) (1.12.11)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.1)
# Requirement already satisfied: six<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.15.0)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.26.3)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.35.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.17.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (1.56.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2018.9)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (57.4.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (21.3)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (3.17.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.2->PyDrive) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.2->PyDrive) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.2->PyDrive) (4.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (3.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2.10)

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':"1m80Sghj2yKDz1KzaFBIC3SMfVo2E_6VG"})
downloaded.GetContentFile('patches.csv')

# %%
import numpy as np
import random
import time
import pdb
import unittest
from PIL import Image
from timeit import default_timer
import matplotlib.pylab as plt
from matplotlib import style
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

style.use('ggplot')
# Finds the L1 distance between two vectors
# u and v are 1-dimensional np.array objects
# TODO: Implement this
def l1(u, v):
    w = 0
    for i in range(len(v)):
        w += abs(float(u[i]) - float(v[i]))
    return w

# Loads the data into a np array, where each row corresponds to
# an image patch -- this step is sort of slow.
# Each row in the data is an image, and there are 400 columns.
def load_data(filename):
    return np.genfromtxt(filename, delimiter=',')

# Creates a hash function from a list of dimensions and thresholds.
def create_function(dimensions, thresholds):
    def f(v):
        boolarray = [v[dimensions[i]] >= thresholds[i] for i in range(len(dimensions))]
        return "".join(map(str, map(int, boolarray)))
    return f

# Creates the LSH functions (functions that compute L K-bit hash keys).
# Each function selects k dimensions (i.e. column indices of the image matrix)
# at random, and then chooses a random threshold for each dimension, between 0 and
# 255.  For any image, if its value on a given dimension is greater than or equal to
# the randomly chosen threshold, we set that bit to 1.  Each hash function returns
# a length-k bit string of the form "0101010001101001...", and the L hash functions 
# will produce L such bit strings for each image.
def create_functions(k, L, num_dimensions=400, min_threshold=0, max_threshold=255):
    functions = []
    for i in range(L):
        dimensions = np.random.randint(low = 0, 
                                   high = num_dimensions,
                                   size = k)
        thresholds = np.random.randint(low = min_threshold, 
                                   high = max_threshold + 1, 
                                   size = k)

        functions.append(create_function(dimensions, thresholds))
    return functions

# Hashes an individual vector (i.e. image).  This produces an array with L
# entries, where each entry is a string of k bits.
def hash_vector(functions, v):
    return np.array([f(v) for f in functions])

# Hashes the data in A, where each row is a datapoint, using the L
# functions in "functions."
def hash_data(functions, A):
    return np.array(list(map(lambda v: hash_vector(functions, v), A)))

# Retrieve all of the points that hash to one of the same buckets 
# as the query point.  Do not do any random sampling (unlike what the first
# part of this problem prescribes).
# Don't retrieve a point if it is the same point as the query point.
def get_candidates(hashed_A, hashed_point, query_index):
    return filter(lambda i: i != query_index and \
        any(hashed_point == hashed_A[i]), range(len(hashed_A)))

# Sets up the LSH.  You should try to call this function as few times as 
# possible, since it is expensive.
# A: The dataset.
# Return the LSH functions and hashed data structure.
def lsh_setup(A, k = 24, L = 10):
    functions = create_functions(k = k, L = L)
    hashed_A = hash_data(functions, A)
    return (functions, hashed_A)

# Run the entire LSH algorithm
def lsh_search(A, hashed_A, functions, query_index, num_neighbors = 3):
    hashed_point = hash_vector(functions, A[query_index, :])
    candidate_row_nums = get_candidates(hashed_A, hashed_point, query_index)
    
    distances = map(lambda r: (r, l1(A[r], A[query_index])), candidate_row_nums)
    best_neighbors = sorted(distances, key=lambda t: t[1])[:num_neighbors]
    s =lambda v: sum([t[1] for t in v])

    return [t[0] for t in best_neighbors],[s(best_neighbors)]


# Plots images at the specified rows and saves them each to files.
def plot(A, row_nums, base_filename):
    for row_num in row_nums:
        patch = np.reshape(A[row_num, :], [20, 20])
        im = Image.fromarray(patch)
        if im.mode != 'RGB':
            im = im.convert('RGB')
        addr = base_filename + "-" + str(row_num) + ".png"
        im.save(addr)
        # img = mpimg.imread(addr)
        # plt.imshow(im)
        return addr

# Finds the nearest neighbors to a given vector, using linear search.
def linear_search(A, query_index, num_neighbors):

    # Extract Query Vector
    query_vect = A[query_index]

    # Compute Distance to Each
    distances = []
    for index,row in enumerate(A):

        # don't include the query
        if index == query_index:
            continue

        # Extract the relevant data from the row
        distance = l1(query_vect, row)

        # This elimination step only works once we found n candidates
        if len(distances) >= num_neighbors:
            # Don't bother adding if it's farther than all "current best" neighbors
            if distance > distances[-1][1]:
                continue

        # Insert in sorted order to optimize
        idx = 0
        for i in range(len(distances)):
            if distances[i][1] > distance:
                idx = i
                break
        distances = distances[: idx] + [[index, distance]] + distances[idx: num_neighbors - 1]
    best_neighbors = sorted(distances, key=lambda t: t[1])[:num_neighbors]
    s =lambda v: sum([t[1] for t in v])

    return [t[0] for t in best_neighbors],[s(best_neighbors)]


# TODO: Write a function that computes the error measure
def lsh_error(lsh_dist, linear_dist):
    error = 0
    for i in range(len(lsh_neighbors)):  # assume same number of searches run for both
        numerator = lsh_dist[i]
        denominator = linear_dist[i]
        # print(numerator)
        # print(denominator)
        error += numerator[0] / denominator[0]
    return error / 10

def plot(A, neighbor_list, base_filename, mark_closest=False):
    label = '[PLOT]'
    outaddrs = []

    # Iterate through all rows in dataframe
    for row,index in enumerate(neighbor_list):
        # print('%8s Plotting Patch %i' % (label, row['index']))

        # Extract patch from row, reformat into 20x20, and convert to Image object
        row_data = np.array(A[row])
        patch = np.reshape(row_data, [20, 20])
        im = Image.fromarray(patch)

        # Ensure image mode is RGB before PNG creation
        if im.mode != 'RGB':
            im = im.convert('RGB')

        # If flagged to mark the closest, add "-closest" into the filename
        if mark_closest:
            outfilename = base_filename + '-' + str(index) + '-closest.png'
            mark_closest = False
        else:
            outfilename = base_filename + '-' + str(index) + '.png'

        # Save the image
        im.save(outfilename)
        # img = mpimg.imread(outfilename)
        # plt.imshow(im)
        outaddrs.append(outfilename)
    return outaddrs

#### TESTS #####

class TestLSH(unittest.TestCase):
    def test_l1(self):
        u = np.array([1, 2, 3, 4])
        v = np.array([2, 3, 2, 3])
        self.assertEqual(l1(u, v), 4)

    def test_hash_data(self):
        f1 = lambda v: sum(v)
        f2 = lambda v: sum([x * x for x in v])
        A = np.array([[1, 2, 3], [4, 5, 6]])
        self.assertEqual(f1(A[0,:]), 6)
        self.assertEqual(f2(A[0,:]), 14)

        functions = [f1, f2]
        self.assertTrue(np.array_equal(hash_vector(functions, A[0, :]), np.array([6, 14])))
        self.assertTrue(np.array_equal(hash_data(functions, A), np.array([[6, 14], [15, 77]])))

    ### TODO: Write your tests here (they won't be graded, 
    ### but you may find them helpful)


if __name__ == '__main__':
    #    unittest.main() ### TODO: Uncomment this to run tests
    #     problem4()
    k = 24
    L = 10
    A = load_data('/content/patches.csv')
    functions = create_functions(k=k,L=L)
    hashed_A = hash_data(functions,A)
    query_indices = [100, 199, 300, 399, 500, 599, 700, 799, 900, 999]
    # query_indices = [100]
    lsh_neighbors = []
    lsh_times = []
    linear_neighbors = []
    linear_times = []
    queries = []
    lsh_distances = []
    linear_distances = []

    for query_index in query_indices:
        print('LSH Search on Index %i' % (query_index))
        start = default_timer()
        lsh_neighbor,lsh_dist = lsh_search(A,hashed_A,functions,query_index, num_neighbors=3)
        # print(lsh_dist)
        print(lsh_neighbor)
        end = default_timer()
        lsh_times.append(end - start)

        print('Linear Search on Index %i' % (query_index))
        start = default_timer()
        linear_neighbor,linear_dist = linear_search(A, query_index, num_neighbors=3)
        # print(linear_dist)
        print(linear_neighbor)
        end = default_timer()
        linear_times.append(end - start)

        lsh_neighbors.append(lsh_neighbor)
        linear_neighbors.append(linear_neighbor)
        lsh_distances.append(lsh_dist)
        linear_distances.append(linear_dist)
    
    # print( 'Plotting Query Patch')
    # plot(A,neighbor_list=[100] , base_filename='output3/query')

#plotting part
    # print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
    # print( 'Plotting LSH Result Patches' )
    # plot( A,neighbor_list=lsh_neighbors[0] , base_filename='output/lsh-match' , mark_closest=True )
    # print( 'Plotting Linear Search Result Patches' )
    # plot( A,linear_neighbors[0] , 'output/linear-match' , mark_closest=True )

    # print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
    # print('Computing Error')
    error = lsh_error(lsh_distances, linear_distances)

    print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
    print('Average LSH Time: %.3f Seconds' % (sum(lsh_times) / len(lsh_times)))
    print('Average Linear Search Time: %.3f Seconds' % ( sum(linear_times) / len(linear_times)))
    print('Error: %f' % (error))
# Out:
# LSH Search on Index 100
# [7551, 8196, 28351]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [21464, 12066, 39910]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [20703, 26600, 10289]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [37216, 41051, 59468]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# []
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 36422]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [37108, 8267, 43311]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [29023, 15184, 20405]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 59238, 18501]
# Linear Search on Index 999
# [46093, 28450, 59238]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Average LSH Time: 0.264 Seconds
# Average Linear Search Time: 12.021 Seconds
# Error: 0.961097

# %%
if __name__ == '__main__':
    k = 24
    errors=[]
    query_indices = [100, 199, 300, 399, 500, 599, 700, 799, 900, 999]
    #query_indices = [100]
    for L in range(10,21,2):
        A = load_data('/content/patches.csv')
        functions = create_functions(k=k,L=L)
        hashed_A = hash_data(functions,A)
        lsh_neighbors = []
        lsh_times = []
        linear_neighbors = []
        linear_times = []
        queries = []
        lsh_distances = []
        linear_distances = []
        

        # Need to run for all query indices to achieve an accurate error measure
        for query_index in query_indices:
            print('LSH Search on Index %i' % (query_index))
            start = default_timer()
            lsh_neighbor,lsh_dist = lsh_search(A,hashed_A,functions,query_index, num_neighbors=3)
            # print(lsh_dist)
            print(lsh_neighbor)
            end = default_timer()
            lsh_times.append(end - start)

            print('Linear Search on Index %i' % (query_index))
            start = default_timer()
            linear_neighbor,linear_dist = linear_search(A, query_index, num_neighbors=3)
            # print(linear_dist)
            print(linear_neighbor)
            end = default_timer()
            linear_times.append(end - start)

            lsh_neighbors.append(lsh_neighbor)
            linear_neighbors.append(linear_neighbor)
            lsh_distances.append(lsh_dist)
            linear_distances.append(linear_dist)
        

        # print('Computing Error')
        error = lsh_error(lsh_distances, linear_distances)
        errors.append(error)
    print(errors)
    Ls = [i for i in range(10,21,2)]
    plt.plot(Ls, errors, '-o', color='darkorange')
    plt.xlabel('L')
    plt.ylabel('error')
    plt.legend(loc='best')
    plt.show()
# Out:
# LSH Search on Index 100
# [7551, 28351, 28251]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [23895, 18032, 34771]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [15818, 22057, 9006]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [20177, 10078, 40954]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [54456, 44414, 575]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 90]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [4469, 8550, 53629]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [15184, 18861, 6373]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 28339, 51830]
# Linear Search on Index 999
# [46093, 28450, 59238]
# LSH Search on Index 100
# [7551, 8196, 28351]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [12066, 38136, 35647]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [22057, 9006, 16448]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [48484, 24280, 52977]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [37232, 17430, 48308]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 36422]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [41454, 2111, 10769]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [29023, 20405, 6585]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [28339, 18225, 18501]
# Linear Search on Index 999
# [46093, 28450, 59238]
# LSH Search on Index 100
# [7551, 28351, 28251]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [38317, 16718, 53727]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [15818, 9006, 16448]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [46641, 19014, 31535]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [16461, 36370, 38841]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 36422]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [42664, 32762, 11604]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [29023, 20405, 6321]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 28450, 28339]
# Linear Search on Index 999
# [46093, 28450, 59238]
# LSH Search on Index 100
# [8196, 28351, 21780]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [39397, 11341, 23895]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [15818, 22057, 9006]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [31535, 36401, 26423]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [26509, 13248, 59028]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 36422]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [24319, 22788, 7654]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [29023, 15184, 20405]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 59238, 28339]
# Linear Search on Index 999
# [46093, 28450, 59238]
# LSH Search on Index 100
# [7551, 8196, 28351]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [21464, 18032, 23550]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [9006, 16448, 39856]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [25421, 8424, 9096]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [46111, 8717, 14263]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 36422]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [52615, 29196, 4469]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [29023, 15184, 20405]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 28450, 59238]
# Linear Search on Index 999
# [46093, 28450, 59238]
# LSH Search on Index 100
# [7551, 8196, 28351]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [43681, 53727, 14077]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [15818, 22057, 9006]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [37380, 14836, 44211]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [59148, 7139, 54456]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 90]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [28487, 1690, 34896]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [29023, 15184, 20405]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 28450, 59238]
# Linear Search on Index 999
# No handles with labels found to put in legend.
# [46093, 28450, 59238]
# [1.0577313467264526, 1.0927541633044024, 1.0654748809184773, 1.0418746015173563, 1.0488276467433093, 1.0587352992632908]

# %%
if __name__ == '__main__':
    L = 10
    query_indices = [100, 199, 300, 399, 500, 599, 700, 799, 900, 999]
    # query_indices = [100]
    errors=[]
    for k in range(16,25,2):
        A = load_data('/content/patches.csv')
        functions = create_functions(k=k,L=L)
        hashed_A = hash_data(functions,A)
        lsh_neighbors = []
        lsh_times = []
        linear_neighbors = []
        linear_times = []
        queries = []
        lsh_distances = []
        linear_distances = []
        

        # Need to run for all query indices to achieve an accurate error measure
        for query_index in query_indices:
            print('LSH Search on Index %i' % (query_index))
            start = default_timer()
            lsh_neighbor,lsh_dist = lsh_search(A,hashed_A,functions,query_index, num_neighbors=3)
            # print(lsh_dist)
            print(lsh_neighbor)
            end = default_timer()
            lsh_times.append(end - start)

            print('Linear Search on Index %i' % (query_index))
            start = default_timer()
            linear_neighbor,linear_dist = linear_search(A, query_index, num_neighbors=3)
            # print(linear_dist)
            print(linear_neighbor)
            end = default_timer()
            linear_times.append(end - start)

            lsh_neighbors.append(lsh_neighbor)
            linear_neighbors.append(linear_neighbor)
            lsh_distances.append(lsh_dist)
            linear_distances.append(linear_dist)
        

        # print('Computing Error')
        error = lsh_error(lsh_distances, linear_distances)
        errors.append(error)
    print(errors)
    ks = [i for i in range(16,25,2)]
    plt.plot(ks, errors, '-o', color='c')
    plt.xlabel('k')
    plt.ylabel('error')
    plt.legend(loc='best')
    plt.show()
# Out:
# LSH Search on Index 100
# [7551, 8196, 28351]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [39397, 21464, 23550]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [15818, 22057, 9006]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [20536, 20177, 33207]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [6201, 47784, 43978]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 36422]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [33741, 13889, 24319]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [29023, 20405, 6321]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 28450, 59238]
# Linear Search on Index 999
# [46093, 28450, 59238]
# LSH Search on Index 100
# [8196, 28351, 28251]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [11341, 57405, 23776]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [15818, 22057, 9006]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [25381, 55862, 24133]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [32947, 42923, 51973]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 36422]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [13889, 12643, 12576]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [29023, 15184, 20405]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 28450, 59238]
# Linear Search on Index 999
# [46093, 28450, 59238]
# LSH Search on Index 100
# [7551, 28351, 28251]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [34771, 24611, 36051]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [15818, 22057, 9006]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [18874, 18892, 17584]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [59148, 16961, 18591]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41168, 3247, 40300]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [8011, 19337, 10066]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [23588, 18861, 51339]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 28450, 59238]
# Linear Search on Index 999
# [46093, 28450, 59238]
# LSH Search on Index 100
# [8196, 28251, 22509]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [42060, 56234, 40686]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [22057, 9006, 16448]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [48555, 24852, 20173]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [8436, 51340, 17135]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 36422, 90]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [12643, 50475, 32254]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [29023, 20405, 6321]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [28450, 59238, 28339]
# Linear Search on Index 999
# [46093, 28450, 59238]
# LSH Search on Index 100
# [7551, 28251, 25289]
# Linear Search on Index 100
# [7551, 8196, 28351]
# LSH Search on Index 199
# [24611, 39389, 15475]
# Linear Search on Index 199
# [39397, 11341, 23895]
# LSH Search on Index 300
# [9006, 20703, 26600]
# Linear Search on Index 300
# [15818, 22057, 9006]
# LSH Search on Index 399
# [9003, 36401, 58394]
# Linear Search on Index 399
# [20536, 18874, 20572]
# LSH Search on Index 500
# [1178, 557, 35904]
# Linear Search on Index 500
# [1178, 557, 35904]
# LSH Search on Index 599
# [59148, 14317, 21921]
# Linear Search on Index 599
# [6201, 47784, 9540]
# LSH Search on Index 700
# [41352, 44006, 36422]
# Linear Search on Index 700
# [41352, 44006, 36422]
# LSH Search on Index 799
# [8937, 18395, 20773]
# Linear Search on Index 799
# [33741, 13889, 24319]
# LSH Search on Index 900
# [6321, 18861, 6373]
# Linear Search on Index 900
# [29023, 15184, 20405]
# LSH Search on Index 999
# [46093, 28450, 28339]
# Linear Search on Index 999
# No handles with labels found to put in legend.
# [46093, 28450, 59238]
# [1.0100040120409262, 1.0523608358705252, 1.0535684123875064, 1.065154041994991, 1.0614501600732436]

# %%
if __name__ == '__main__':
    #    unittest.main() ### TODO: Uncomment this to run tests
    #     problem4()
    k = 24
    L = 10
    A = load_data('/content/patches.csv')
    functions = create_functions(k=k,L=L)
    hashed_A = hash_data(functions,A)
    # query_indices = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
    query_indices = [100]
    lsh_neighbors = []
    lsh_times = []
    linear_neighbors = []
    linear_times = []
    queries = []
    lsh_distances = []
    linear_distances = []

    for query_index in query_indices:
        print('LSH Search on Index %i' % (query_index))
        start = default_timer()
        lsh_neighbor,lsh_dist = lsh_search(A,hashed_A,functions,query_index, num_neighbors=10)
        # print(lsh_dist)
        print(lsh_neighbor)
        end = default_timer()
        lsh_times.append(end - start)

        print('Linear Search on Index %i' % (query_index))
        start = default_timer()
        linear_neighbor,linear_dist = linear_search(A, query_index, num_neighbors=10)
        # print(linear_dist)
        print(linear_neighbor)
        end = default_timer()
        linear_times.append(end - start)

        lsh_neighbors.append(lsh_neighbor)
        linear_neighbors.append(linear_neighbor)
        lsh_distances.append(lsh_dist)
        linear_distances.append(linear_dist)
    
    print( 'Saving Query Patch ...')
    addr = plot(A, neighbor_list=[100] , base_filename='output_images/query')
#plotting part
    print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
    print( 'Saving LSH Result Patches ...' )
    lshout = plot( A,neighbor_list=lsh_neighbors[0] , base_filename='output_images/lsh-match' , mark_closest=True )
    
    print( 'Saving Linear Search Result Patches ...' )
    linout = plot( A,linear_neighbors[0] , 'output_images/linear-match' , mark_closest=True )
# Out:
# LSH Search on Index 100
# [7551, 8196, 28351, 28251, 25289, 21780, 22509, 12444, 25549, 7464]
# Linear Search on Index 100
# [7551, 8196, 28351, 28251, 25289, 21780, 22509, 12444, 25549, 7464]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
