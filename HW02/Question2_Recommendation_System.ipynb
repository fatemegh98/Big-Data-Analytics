# %%
import csv
import numpy as np
import pandas as pd
from scipy.sparse import lil_matrix, csc_matrix
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

data = pd.read_csv('ratings.csv')
games = pd.read_csv('games.csv')

# %%
data.head(5)
# Out:
#    game_id  user_id  rating
# 0        1      314     5.0
# 1        1      439     3.0
# 2        1      588     5.0
# 3        1     1169     4.0
# 4        1     1185     4.0

# %%
print(data[data['rating'].isnull()])
# Out:
#         game_id  user_id  rating
# 236341     2366       24     NaN

# %%
data = data.dropna(subset=['rating'])
print(data[data['rating'].isnull()])
# Out:
# Empty DataFrame
# Columns: [game_id, user_id, rating]
# Index: []

# %%
m = data['user_id'].max() + 1 # number of user
n = data['game_id'].max() + 1 # number of item

R = lil_matrix((m, n))
for i, r in data.iterrows():
    R[int(r.user_id), int(r.game_id)] = r.rating
R = R.tocsc()

P = lil_matrix((m, m))
for i in range(m):
    P[i, i] = data[data.user_id == i].sum().rating
P = P.tocsc()

Q = lil_matrix((n, n))
for i in range(n):
    Q[i, i] = data[data.game_id == i].sum().rating
Q = Q.tocsc()

print('R.shape: ', R.shape)
print('P.shape: ', P.shape)
print('Q.shape: ', Q.shape)
# Out:
# R.shape:  (53425, 2367)
# P.shape:  (53425, 53425)
# Q.shape:  (2367, 2367)

# %% [markdown]
# # Item-Item collaborative filtering

# %%
mask = Q != 0
Q_star = Q.copy()
Q_star[mask] = np.sqrt(Q_star[mask])
Q_star[mask] = 1 / Q_star[mask]

Γ_ij = R * Q_star * R.transpose() * R * Q_star
Γ_ij
# Out:
# <53425x2367 sparse matrix of type '<class 'numpy.float64'>'
# 	with 24529136 stored elements in Compressed Sparse Column format>

# %%
Γ_ij.shape
# Out:
# (53425, 2367)

# %%
row = Γ_ij.getrow(5461).toarray().reshape((-1))
print(row)
ind = np.argpartition(row, -5)[-5:]
results = games[games.game_id.isin(ind[np.flip(np.argsort(row[ind]))])]
results['recommendation_score'] = row[ind[np.flip(np.argsort(row[ind]))]]
results
# Out:
# [0.00000000e+00 6.73797865e+02 7.52854372e+02 ... 1.49436702e-01
#  1.28195217e+02 6.80483947e+01]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#      game_id                 name release_date  \
# 3        4.0          SoulCalibur     8-Sep-99
# 4        5.0   Super Mario Galaxy    12-Nov-07
# 14      15.0  Super Mario Odyssey    27-Oct-17
# 41      42.0               Halo 2     9-Nov-04
# 117    118.0       SoulCalibur II    27-Aug-03
#
#                                                summary  meta_score  \
# 3    This is a tale of souls and swords, transcendi...        98.0
# 4    [Metacritic's 2007 Wii Game of the Year] The u...        97.0
# 14   New Evolution of Mario Sandbox-Style Gameplay....        97.0
# 41   The Covenant alien race threatens to destroy a...        95.0
# 117  Open the next chapter in world of Soul Calibur...        93.0
#
#      recommendation_score
# 3              768.432988
# 4              767.131608
# 14             766.948801
# 41             766.667109
# 117            762.831341

# %%
row = Γ_ij.getrow(10140).toarray().reshape((-1))
ind = np.argpartition(row, -5)[-5:]
results = games[games.game_id.isin(ind[np.flip(np.argsort(row[ind]))])]
results['recommendation_score'] = row[ind[np.flip(np.argsort(row[ind]))]]
results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#     game_id                      name release_date  \
# 1       2.0  Tony Hawk's Pro Skater 2    20-Sep-00
# 3       4.0               SoulCalibur     8-Sep-99
# 6       7.0     Red Dead Redemption 2    26-Oct-18
# 14     15.0       Super Mario Odyssey    27-Oct-17
# 41     42.0                    Halo 2     9-Nov-04
#
#                                               summary  meta_score  \
# 1   As most major publishers' development efforts ...        98.0
# 3   This is a tale of souls and swords, transcendi...        98.0
# 6   Developed by the creators of Grand Theft Auto ...        97.0
# 14  New Evolution of Mario Sandbox-Style Gameplay....        97.0
# 41  The Covenant alien race threatens to destroy a...        95.0
#
#     recommendation_score
# 1             589.718898
# 3             581.086122
# 6             569.842213
# 14            562.506302
# 41            558.266647

# %% [markdown]
# # User-User collaborative filtering

# %%
# P_star = 1 / np.sqrt(P)
# P_star[P_star == np.inf] = 0

mask = P != 0
P_star = P.copy()
P_star[mask] = np.sqrt(P_star[mask])
P_star[mask] = 1 / P_star[mask]

# %%
Γ_u = P_star * R * R.transpose() * P_star * R
Γ_u
# Out:
# <53425x2367 sparse matrix of type '<class 'numpy.float64'>'
# 	with 24529136 stored elements in Compressed Sparse Column format>

# %%
row = Γ_u.getrow(5461).toarray().reshape((-1))
ind = np.argpartition(row, -5)[-5:]
results = games[games.game_id.isin(ind[np.flip(np.argsort(row[ind]))])]
results['recommendation_score'] = row[ind[np.flip(np.argsort(row[ind]))]]
results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#      game_id                                 name release_date  \
# 3        4.0                          SoulCalibur     8-Sep-99
# 14      15.0                  Super Mario Odyssey    27-Oct-17
# 30      31.0  The Legend of Zelda: The Wind Waker    24-Mar-03
# 41      42.0                               Halo 2     9-Nov-04
# 264    265.0                        Resident Evil    30-Mar-96
#
#                                                summary  meta_score  \
# 3    This is a tale of souls and swords, transcendi...        98.0
# 14   New Evolution of Mario Sandbox-Style Gameplay....        97.0
# 30   In this ninth entry in the Legend of Zelda ser...        96.0
# 41   The Covenant alien race threatens to destroy a...        95.0
# 264  Raccoon City has been completely overrun by mu...        91.0
#
#      recommendation_score
# 3              493.963613
# 14             481.479671
# 30             476.905938
# 41             476.046984
# 264            471.184601

# %%
row = Γ_u.getrow(10140).toarray().reshape((-1))
ind = np.argpartition(row, -5)[-5:]
results = games[games.game_id.isin(ind[np.flip(np.argsort(row[ind]))])]
results['recommendation_score'] = row[ind[np.flip(np.argsort(row[ind]))]]
results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#     game_id                                 name release_date  \
# 1       2.0             Tony Hawk's Pro Skater 2    20-Sep-00
# 3       4.0                          SoulCalibur     8-Sep-99
# 14     15.0                  Super Mario Odyssey    27-Oct-17
# 30     31.0  The Legend of Zelda: The Wind Waker    24-Mar-03
# 41     42.0                               Halo 2     9-Nov-04
#
#                                               summary  meta_score  \
# 1   As most major publishers' development efforts ...        98.0
# 3   This is a tale of souls and swords, transcendi...        98.0
# 14  New Evolution of Mario Sandbox-Style Gameplay....        97.0
# 30  In this ninth entry in the Legend of Zelda ser...        96.0
# 41  The Covenant alien race threatens to destroy a...        95.0
#
#     recommendation_score
# 1             429.950483
# 3             410.184308
# 14            400.650240
# 30            392.361418
# 41            390.987440
